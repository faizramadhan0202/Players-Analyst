# %% [markdown]
# ## <center>Players Analysis<center/>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime
import missingno as mno

import ipywidgets as widgets
from ipywidgets import interact
from ipywidgets import interact_manual

plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('C:\laragon\www\players\data-1.csv')

# %%
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df.shape
# Out:
# (18207, 89)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0          int64
# ID                  int64
# Name               object
# Age                 int64
# Photo              object
#                    ...
# GKHandling        float64
# GKKicking         float64
# GKPositioning     float64
# GKReflexes        float64
# Release Clause     object
# Length: 89, dtype: object

# %%
#Lets describe the data for the numerical Column
df.iloc[:, 2:].describe().style.background_gradient(cmap='cividis')
# Out:
# <style  type="text/css" >
#     #T_365c8c30_f7eb_11ed_beec_82983b6426ecrow0_col0 {
#             background-color:  #fee838;
#             color:  #000000;
#         }    #T_365c8c30_f7eb_11ed_beec_82983b6426ecrow0_col1 {
#             background-color:  #fee838;
#             color:  #000000;
#         }    #T_365c8c30_f7eb_11ed_beec_82983b6426ecrow0_col2 {
#             background-color:  #fee838;
#             color:  #000000;
#         }    #T_365c8c30_f7eb_11ed_beec_82983b6426ecrow0_col3 {
#             background-color:  #fee838;
#             color:  #000000;
#         }    #T_365c8c30_f7eb_11ed_beec_82983b6426ecrow0_col4 {
#             background-color:  #fee838;
#             color:  #000000;
#         }    #T_365c8c30_f7eb_11ed_beec_82983b6426ecrow0_col5 {
#             background-color:  #fee838;
#             color:  #000000;
#         }    #T_365c8c30_f7eb_11ed_beec_82983b6426ecrow0_col6 {
#             background-color:  #fee838;
#             color:  #000000;
# ...

# %%
#Lets check the describe statistics for the categorial columns as well
df.iloc[:, 13:].describe(include='object')
# Out:
#        Preferred Foot       Work Rate Body Type Real Face Position  \
# count           18159           18159     18159     18159    18147
# unique              2               9        10         2       27
# top             Right  Medium/ Medium    Normal        No       ST
# freq            13948            9810     10595     16505     2152
#
#              Joined Loaned From Contract Valid Until Height  Weight  ...  \
# count         16654        1264                17918  18159   18159  ...
# unique         1736         341                   36     21      57  ...
# top     Jul 1, 2018    Atalanta                 2019    6'0  165lbs  ...
# freq           1538          20                 4819   2881    1483  ...
#
#           LDM    CDM    RDM    RWB     LB    LCB     CB    RCB     RB  \
# count   16122  16122  16122  16122  16122  16122  16122  16122  16122
# unique     99     99     99     95     98    108    108    108     98
# ...

# %% [markdown]
# ## Cleaning Data

# %%
#check if the data contains any null value 
mno.bar(df.iloc[:, 40:],
        color= 'orange',
        sort= 'ascending')
plt.title('Check Missing Value heat map for first halft of data', fontsize=14)
plt.show()

# %%
#check missing value a as matrix
mno.bar(df.iloc[:, 40:])
plt.title('Check Missing Value heat map for second halft of data', fontsize=14)
plt.show()

# %%
#filling the missing value for the continous variables for proper data visualization\n"
df['ShortPassing'].fillna(df['ShortPassing'].mean(), inplace = True)
df['Volleys'].fillna(df['Volleys'].mean(), inplace = True)
df['Dribbling'].fillna(df['Dribbling'].mean(), inplace = True)
df['Curve'].fillna(df['Curve'].mean(), inplace = True)
df['FKAccuracy'].fillna(df['FKAccuracy'], inplace = True)
df['LongPassing'].fillna(df['LongPassing'].mean(), inplace = True)
df['BallControl'].fillna(df['BallControl'].mean(), inplace = True)
df['HeadingAccuracy'].fillna(df['HeadingAccuracy'].mean(), inplace = True)
df['Finishing'].fillna(df['Finishing'].mean(), inplace = True)
df['Crossing'].fillna(df['Crossing'].mean(), inplace = True)
df['Weight'].fillna('200lbs', inplace = True)
df['Contract Valid Until'].fillna(2019, inplace = True)
df['Height'].fillna("5'11", inplace = True)
df['Loaned From'].fillna('None', inplace = True)
df['Joined'].fillna('Jul 1, 2018', inplace = True)
df['Jersey Number'].fillna(8, inplace = True)
df['Body Type'].fillna('Normal', inplace = True)
df['Position'].fillna('ST', inplace = True)
df['Club'].fillna('No Club', inplace = True)
df['Work Rate'].fillna('Medium/ Medium', inplace = True)
df['Skill Moves'].fillna(df['Skill Moves'].median(), inplace = True)
df['Weak Foot'].fillna(3, inplace = True)
df['Preferred Foot'].fillna('Right', inplace = True)
df['International Reputation'].fillna(1, inplace = True)
df['Wage'].fillna('€200K', inplace = True)


df.fillna(0, inplace = True)

# %%
#lets check wheater the data still has many missing value
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Feature Engineering

# %%
#creating new features by aggregating the features

data = df

def defending(data):
    return int(round((data[['Marking', 'StandingTackle',
                                   'SlidingTackle']].mean()).mean()))    
def general(data):
    return int(round((data[['HeadingAccuracy', 'Dribbling', 'Curve',
                                  'BallControl']].mean()).mean()))
def mental(data):
    return int(round((data[['Aggression', 'Interceptions', 'Positioning',
                                  'Vision','Composure']].mean()).mean()))
def passing(data):
    return int(round((data[['Crossing', 'ShortPassing',
                                   'LongPassing']].mean()).mean()))
def mobility(data):
    return int(round((data[['Acceleration', 'SprintSpeed',
                                   'Agility','Reactions']].mean()).mean()))
def power(data):
    return int(round((data[['Balance', 'Jumping', 'Stamina',
                                   'Strength']].mean()).mean()))
def rating(data):
    return int(round((data[['Potential', 'Overall']].mean()).mean()))
    
def shooting(data):
    return int(round((data[['Finishing', 'Volleys', 'FKAccuracy',
                                   'ShotPower','LongShots', 'Penalties']].mean()).mean()))

# %%
# adding these categories to the data

data['Defending'] = data.apply(defending, axis = 1)
data['General'] = data.apply(general, axis = 1)
data['Mental'] = data.apply(mental, axis = 1)
data['Passing'] = data.apply(passing, axis = 1)
data['Mobility'] = data.apply(mobility, axis = 1)
data['Power'] = data.apply(power, axis = 1)
data['Rating'] = data.apply(rating, axis = 1)
data['Shooting'] = data.apply(shooting, axis = 1)

# lets check the column names in the data after adding new features
data.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
#list Category to Plot
cat_vars = ['Defending', 'Passing', 'Rating', 'Shooting']
             
#create figure with subplot
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(20, 25))
axs = axs.ravel()

#create bar plot for each category list
for i, var in enumerate(cat_vars):
    sns.barplot(x=var, y='Position', data=df, ax=axs[i], estimator=np.mean)
    axs[i].tick_params(rotation=90)
    
#adjust spasing between subplots
fig.tight_layout()

#show plot
plt.show()

# %%
#comparison of preferred foot over the diffrent players

plt.rcParams['figure.figsize'] = (10,5)
sns.countplot(data['Preferred Foot'], palette='pink')
plt.title('Most preferred foot over the diffrent player', fontsize=15)
plt.show()

# %%
#Ploting chart reputation international

labels = ['1','2','3','4','5']
sizes = data['International Reputation'].value_counts()
colors = plt.cm.copper(np.linspace(0,1,5))
explode = [0.1,0.1,0.2,0.5,0.9]

plt.rcParams['figure.figsize'] = (9,9)
plt.pie(sizes, labels = labels, colors = colors, explode = explode, shadow = True)
plt.title('Reputation Players International', fontsize = 15)
plt.legend()
plt.show()

# %%
#
data[data['International Reputation'] == 5][['Name', 'Nationality', 
                                            'Overall']].sort_values(by = 'Overall', 
                                                                    ascending = False).style.background_gradient(cmap = 'magma')
# Out:
# <style  type="text/css" >
#     #T_a7c1a659_fd48_11ed_95d8_b01849a93aa4row0_col2 {
#             background-color:  #fcfdbf;
#             color:  #000000;
#         }    #T_a7c1a659_fd48_11ed_95d8_b01849a93aa4row1_col2 {
#             background-color:  #fcfdbf;
#             color:  #000000;
#         }    #T_a7c1a659_fd48_11ed_95d8_b01849a93aa4row2_col2 {
#             background-color:  #fd9668;
#             color:  #000000;
#         }    #T_a7c1a659_fd48_11ed_95d8_b01849a93aa4row3_col2 {
#             background-color:  #f1605d;
#             color:  #000000;
#         }    #T_a7c1a659_fd48_11ed_95d8_b01849a93aa4row4_col2 {
#             background-color:  #9e2f7f;
#             color:  #f1f1f1;
#         }    #T_a7c1a659_fd48_11ed_95d8_b01849a93aa4row5_col2 {
#             background-color:  #000004;
#             color:  #f1f1f1;
# ...

# %%
#plot a pie chart to present the share of the week plyaers

labels = ['1','2','3','4','5']
sizes = data['Weak Foot'].value_counts()
colors = plt.cm.Wistia(np.linspace(0,1,5))
explode = [0, 0, 0, 0, 0.1]

plt.rcParams['figure.figsize'] = (9,9)
plt.pie(sizes, labels = labels, colors = colors, explode = explode, shadow = True, startangle = 90)
plt.title('Distribution of Waek Foot Among Players', fontsize = 15)
plt.legend()
plt.show()

# %%
#Diffrent Position acquire by players

plt.figure(figsize = (13, 15))
plt.style.use('fivethirtyeight')

ax = sns.countplot(y = 'Position', data = data, palette = 'bone')
ax.set_xlabel(xlabel = 'Diffrent Position in Football', fontsize = 15)
ax.set_ylabel(ylabel = 'Count of Players')
ax.set_title(label = 'Comprasition of Position and Players ', fontsize= 20)
plt.show()

# %%
#defining a function for cleaning the weight data

def extract_value_from(value):
    out = value.replace('lbs', '')
    return float(out)

#applying 
data['Weight'] = data['Weight'].apply(lambda x : extract_value_from(x))

#plotting the distribution of  the weight of the players
sns.distplot(data['Weight'], color = 'black')
plt.title('Distribution of The Players Weight', fontsize = 15)
plt.show()

# %%
#defining a function for cleaning the wage column

def extract_value_from(column):
    out = column.replace('€', '')
    if 'M' in out:
        out = float(out.replace('M', ''))*1000000
    elif 'K' in column:
        out = float(out.replace('K', ''))*1000
    return float(out)

# %%
#applying the function to the wage and value column

vl = data['Value'].astype(str)
wg = data['Wage'].astype(str)

data_value = vl.apply(lambda x: extract_value_from(x))
data_wage = wg.apply(lambda x: extract_value_from(x))

'''data['Value'] = data['Value'].apply(lambda x: extract_value_from(x))
data['Wage'] = data['Wage'].apply(lambda x: extract_value_from(x))'''

#Visualization
plt.rcParams['figure.figsize'] = (16, 5)
plt.subplot(1, 2, 1)
sns.distplot(data_value, color = 'salmon')
plt.title('Distribution of Value of The Players')

plt.subplot(1, 2, 2)
sns.distplot(data_wage, color = 'purple')
plt.title('Distribution of Wages of The Players')
plt.show()

# %%
#Skill Move the Players

plt.figure(figsize = (10, 6))
ax = sns.countplot(x = 'Skill Moves', data = data, palette = 'pastel')
ax.set_title('Count of Players Skill Move')
ax.set_xlabel(xlabel = 'Number of skill Move', fontsize = 15)
ax.set_ylabel(ylabel = 'count', fontsize = 15)
plt.show()

# %%
#to show Different work rate the players participatial the FIFA 2019

plt.figure(figsize = (15, 5))
plt.style.use('fivethirtyeight')

sns.countplot(x = 'Work Rate', data = data, palette = 'hls')
plt.title('Diffrent Work Rate The Players Participatial The FIFA 2019')
plt.xlabel(xlabel = 'Work Rates Associated With Players', fontsize = 15)
plt.ylabel(ylabel = 'Count of Players', fontsize = 15)
plt.xticks(rotation = 90)
plt.show()

# %%
#to Show Different Pontential scores of the players participating in the FIFA 2019

plt.figure(figsize=(16,4))
plt.style.use('seaborn-paper')

plt.subplot(1, 2, 1)
x = data.Potential
ax = sns.distplot(x, bins = 58, kde = False, color = 'y')
ax.set_xlabel(xlabel = 'Players Pontetial Score', fontsize = 10)
ax.set_ylabel(ylabel = 'Number Of Players', fontsize = 15)
ax.set_title('Histogram of Players Pontetial Score')

plt.subplot(1, 2, 2)
x = data.Overall
ax = sns.distplot(x, bins = 58, kde = False, color = 'y')
ax.set_xlabel(xlabel = 'Players Pontetial Score', fontsize = 10)
ax.set_ylabel(ylabel = 'Number Of Players', fontsize = 15)
ax.set_title('Histogram of Players Pontetial Score')
plt.show()

# %%
#violin Plot

plt.rcParams['figure.figsize'] = (15, 4)
plt.style.use('seaborn-dark-palette')

sns.boxplot(data['Overall'], data['Age'], hue = data['Preferred Foot'], palette = 'Greys')
plt.title('Comparision of Overall Scores and Age Preferred Foot')
plt.show()
